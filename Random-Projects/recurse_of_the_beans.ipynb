# %% [markdown]
# # WikiBeania - Gathering All of the Knowledge on Beans

# %% [markdown]
# Beans are everywhere, no doubt about that. But one comment that often comes up in many bean lectures I have attended is: there are too many beans! I can't keep track of all of my beans! How many beans does it take to get to the center of a tootsie pop?
#
# To them I say, "you are right." There is no central hub of knowledge for beans. When I google searched "how many beans are there?" Do you know what was returned? Nothing helpful..
#
# Therefore, I am proposing to build a knowledge center for beans, or as we have decided to call it, WikiBeania.

# %%
# Lets get some helper beans
import wikipediaapi as wikibeaniaapi
import re as clean_beans

# %% [markdown]
# WikiBeania directly plagiarizes and copies results from Wikipedia, a common internet site to understand more about certain topics. But the vastness of Wikipedia can often be overwhelming, especially for large topics, such as Beans.

# %%
# lets connect to wikipedia and name it wikibeania
wikibeania = wikibeaniaapi.Wikipedia(
        language='en',
        extract_format=wikibeaniaapi.ExtractFormat.WIKI
)

# run a quick test to take a look at the original bean wikibeania page
try:
    the_original_bean = wikibeania.page('Bean')
    print("Connected to Beans")
except:
    print("Alert! Bean Connection Failed")
# Out:
# Connected to Beans

# %%
the_original_bean.exists()
# Out:
# True

# %% [markdown]
# __Excellent__ we are connected to a wikibeania bean

# %%
# Lets learn more
the_original_bean.summary
# Out:
# 'A bean is the seed of one of several genera of the flowering plant family Fabaceae, which are used as vegetables for human or animal food. They can be cooked in many different ways, including boiling, frying, and baking, and are used in several traditional dishes throughout the world.'

# %% [markdown]
# __Wow__ what knowledge of beans

# %% [markdown]
# Lets dig in a bit deeper and see how many beans are referenced in this wikibeania bean

# %%
bean_searcher = clean_beans.compile(r'\bbean\b|\bbeans\b', flags=clean_beans.IGNORECASE)
how_many_beans = bean_searcher.findall(the_original_bean.text)

# %%
print("There were {} beans referenced in the og bean".format(len(how_many_beans)))
# Out:
# There were 114 beans referenced in the og bean

# %% [markdown]
# __How stunning__

# %%
# lets make a quick function to see what a wikibeania bean references
def print_beans(bean_page):
        bean_links = bean_page.links
        for bean_title in sorted(bean_links.keys()):
            print("%s: %s" % (bean_title, bean_links[bean_title]))

# %%
print_beans(the_original_bean)
# Out:
# Adzuki bean: Adzuki bean (id: ??, ns: 0)
# Afghanistan: Afghanistan (id: ??, ns: 0)
# Alfalfa: Alfalfa (id: ??, ns: 0)
# Ancient Egypt: Ancient Egypt (id: ??, ns: 0)
# Annibale Carracci: Annibale Carracci (id: ??, ns: 0)
# Antinutrient: Antinutrient (id: ??, ns: 0)
# Appaloosa bean: Appaloosa bean (id: ??, ns: 0)
# Arachis: Arachis (id: ??, ns: 0)
# Arachis hypogaea: Arachis hypogaea (id: ??, ns: 0)
# Bacteria: Bacteria (id: ??, ns: 0)
# Bad Bug Book: Bad Bug Book (id: ??, ns: 0)
# Bahamas: Bahamas (id: ??, ns: 0)
# Baked beans: Baked beans (id: ??, ns: 0)
# Bean (disambiguation): Bean (disambiguation) (id: ??, ns: 0)
# Beansprout: Beansprout (id: ??, ns: 0)
# Bibcode (identifier): Bibcode (identifier) (id: ??, ns: 0)
# Black gram: Black gram (id: ??, ns: 0)
# Black turtle bean: Black turtle bean (id: ??, ns: 0)
# Black-eyed pea: Black-eyed pea (id: ??, ns: 0)
# Brazil: Brazil (id: ??, ns: 0)
# Broad bean: Broad bean (id: ??, ns: 0)
# Broad beans: Broad beans (id: ??, ns: 0)
# Cabbage: Cabbage (id: ??, ns: 0)
# Cajanus: Cajanus (id: ??, ns: 0)
# Cajanus cajan: Cajanus cajan (id: ??, ns: 0)
# Calypso bean: Calypso bean (id: ??, ns: 0)
# Canavalia: Canavalia (id: ??, ns: 0)
# Canavalia ensiformis: Canavalia ensiformis (id: ??, ns: 0)
# Canavalia gladiata: Canavalia gladiata (id: ??, ns: 0)
# Carbohydrate: Carbohydrate (id: ??, ns: 0)
# Category:Articles containing potentially dated statements from 2008: Category:Articles containing potentially dated statements from 2008 (id: ??, ns: 14)
# Category:Use dmy dates from March 2015: Category:Use dmy dates from March 2015 (id: ??, ns: 14)
# Category:Wikipedia articles needing clarification from November 2017: Category:Wikipedia articles needing clarification from November 2017 (id: ??, ns: 14)
# Category:Wikipedia articles with LCCN identifiers: Category:Wikipedia articles with LCCN identifiers (id: ??, ns: 14)
# Category:Wikipedia articles with NARA identifiers: Category:Wikipedia articles with NARA identifiers (id: ??, ns: 14)
# Category:Wikipedia articles with NDL identifiers: Category:Wikipedia articles with NDL identifiers (id: ??, ns: 14)
# Chickpea: Chickpea (id: ??, ns: 0)
# China: China (id: ??, ns: 0)
# Cholesterol: Cholesterol (id: ??, ns: 0)
# Christopher Columbus: Christopher Columbus (id: ??, ns: 0)
# Cicer: Cicer (id: ??, ns: 0)
# Clover: Clover (id: ??, ns: 0)
# Cocoa bean: Cocoa bean (id: ??, ns: 0)
# Coffee bean: Coffee bean (id: ??, ns: 0)
# Cognate: Cognate (id: ??, ns: 0)
# Common bean: Common bean (id: ??, ns: 0)
# Companion plant: Companion plant (id: ??, ns: 0)
# Cowpea: Cowpea (id: ??, ns: 0)
# Cyamopsis: Cyamopsis (id: ??, ns: 0)
# Cyamopsis tetragonoloba: Cyamopsis tetragonoloba (id: ??, ns: 0)
# Dietary Reference Intake: Dietary Reference Intake (id: ??, ns: 0)
# Doi (identifier): Doi (identifier) (id: ??, ns: 0)
# Edward Mellanby: Edward Mellanby (id: ??, ns: 0)
# Encyclopedia Britannica: Encyclopedia Britannica (id: ??, ns: 0)
# Enzyme: Enzyme (id: ??, ns: 0)
# Escherichia coli: Escherichia coli (id: ??, ns: 0)
# Fabaceae: Fabaceae (id: ??, ns: 0)
# Falafel: Falafel (id: ??, ns: 0)
# Family (biology): Family (biology) (id: ??, ns: 0)
# Fassoulada: Fassoulada (id: ??, ns: 0)
# Fat: Fat (id: ??, ns: 0)
# Fermentation (food): Fermentation (food) (id: ??, ns: 0)
# Flatulence: Flatulence (id: ??, ns: 0)
# Flowering plant: Flowering plant (id: ??, ns: 0)
# Folate: Folate (id: ??, ns: 0)
# Food and Agriculture Organization: Food and Agriculture Organization (id: ??, ns: 0)
# Food and Drug Administration: Food and Drug Administration (id: ??, ns: 0)
# Food energy: Food energy (id: ??, ns: 0)
# Food poisoning: Food poisoning (id: ??, ns: 0)
# Forage: Forage (id: ??, ns: 0)
# Genus: Genus (id: ??, ns: 0)
# German language: German language (id: ??, ns: 0)
# Glycine (plant): Glycine (plant) (id: ??, ns: 0)
# Glycine max: Glycine max (id: ??, ns: 0)
# Green bean: Green bean (id: ??, ns: 0)
# Green gram: Green gram (id: ??, ns: 0)
# Guitarrero Cave: Guitarrero Cave (id: ??, ns: 0)
# Hay: Hay (id: ??, ns: 0)
# Heirloom plant: Heirloom plant (id: ??, ns: 0)
# Heliotropic: Heliotropic (id: ??, ns: 0)
# Help:Authority control: Help:Authority control (id: ??, ns: 12)
# ISBN (identifier): ISBN (identifier) (id: ??, ns: 0)
# ISSN (identifier): ISSN (identifier) (id: ??, ns: 0)
# Iliad: Iliad (id: ??, ns: 0)
# India: India (id: ??, ns: 0)
# International unit: International unit (id: ??, ns: 0)
# Iron: Iron (id: ??, ns: 0)
# Kenya: Kenya (id: ??, ns: 0)
# Kidney bean: Kidney bean (id: ??, ns: 0)
# LCCN (identifier): LCCN (identifier) (id: ??, ns: 0)
# Lablab: Lablab (id: ??, ns: 0)
# Lablab purpureus: Lablab purpureus (id: ??, ns: 0)
# Lathyrus: Lathyrus (id: ??, ns: 0)
# Lathyrus sativus: Lathyrus sativus (id: ??, ns: 0)
# Lathyrus tuberosus: Lathyrus tuberosus (id: ??, ns: 0)
# Lectin: Lectin (id: ??, ns: 0)
# Legume: Legume (id: ??, ns: 0)
# Lens (plant): Lens (plant) (id: ??, ns: 0)
# Lens culinaris: Lens culinaris (id: ??, ns: 0)
# Lima bean: Lima bean (id: ??, ns: 0)
# Linguistic prescription: Linguistic prescription (id: ??, ns: 0)
# List of bean soups: List of bean soups (id: ??, ns: 0)
# List of edible seeds: List of edible seeds (id: ??, ns: 0)
# List of legume dishes: List of legume dishes (id: ??, ns: 0)
# Listeria: Listeria (id: ??, ns: 0)
# Lupinus: Lupinus (id: ??, ns: 0)
# Lupinus albus: Lupinus albus (id: ??, ns: 0)
# Lupinus mutabilis: Lupinus mutabilis (id: ??, ns: 0)
# Macrotyloma: Macrotyloma (id: ??, ns: 0)
# Macrotyloma uniflorum: Macrotyloma uniflorum (id: ??, ns: 0)
# Maize: Maize (id: ??, ns: 0)
# Merriam-Webster: Merriam-Webster (id: ??, ns: 0)
# Mesoamerica: Mesoamerica (id: ??, ns: 0)
# Mexico: Mexico (id: ??, ns: 0)
# Microgram: Microgram (id: ??, ns: 0)
# Milligram: Milligram (id: ??, ns: 0)
# Moth bean: Moth bean (id: ??, ns: 0)
# Mucuna: Mucuna (id: ??, ns: 0)
# Mucuna pruriens: Mucuna pruriens (id: ??, ns: 0)
# Mung bean: Mung bean (id: ??, ns: 0)
# Myanmar: Myanmar (id: ??, ns: 0)
# National Archives and Records Administration: National Archives and Records Administration (id: ??, ns: 0)
# National Diet Library: National Diet Library (id: ??, ns: 0)
# National Poisons Information Service: National Poisons Information Service (id: ??, ns: 0)
# New World: New World (id: ??, ns: 0)
# Nitrogen: Nitrogen (id: ??, ns: 0)
# Oligosaccharide: Oligosaccharide (id: ??, ns: 0)
# PMC (identifier): PMC (identifier) (id: ??, ns: 0)
# PMID (identifier): PMID (identifier) (id: ??, ns: 0)
# Pea: Pea (id: ??, ns: 0)
# Peru: Peru (id: ??, ns: 0)
# Phaseolus: Phaseolus (id: ??, ns: 0)
# Phaseolus acutifolius: Phaseolus acutifolius (id: ??, ns: 0)
# Phaseolus coccineus: Phaseolus coccineus (id: ??, ns: 0)
# Phaseolus lunatus: Phaseolus lunatus (id: ??, ns: 0)
# Phaseolus polyanthus: Phaseolus polyanthus (id: ??, ns: 0)
# Phaseolus vulgaris: Phaseolus vulgaris (id: ??, ns: 0)
# Phytic acid: Phytic acid (id: ??, ns: 0)
# Phytohaemagglutinin: Phytohaemagglutinin (id: ??, ns: 0)
# Pinto bean: Pinto bean (id: ??, ns: 0)
# Pisum: Pisum (id: ??, ns: 0)
# Plant stem: Plant stem (id: ??, ns: 0)
# Portal:Agriculture and Agronomy: Portal:Agriculture and Agronomy (id: ??, ns: 100)
# Portal:Food: Portal:Food (id: ??, ns: 100)
# Protein (nutrient): Protein (nutrient) (id: ??, ns: 0)
# Protein in nutrition: Protein in nutrition (id: ??, ns: 0)
# Psophocarpus: Psophocarpus (id: ??, ns: 0)
# Psophocarpus tetragonolobus: Psophocarpus tetragonolobus (id: ??, ns: 0)
# Raffinose: Raffinose (id: ??, ns: 0)
# Ricinus: Ricinus (id: ??, ns: 0)
# Runner bean: Runner bean (id: ??, ns: 0)
# Rwanda: Rwanda (id: ??, ns: 0)
# Salmonella: Salmonella (id: ??, ns: 0)
# Shallow frying: Shallow frying (id: ??, ns: 0)
# Silage: Silage (id: ??, ns: 0)
# Slow cooker: Slow cooker (id: ??, ns: 0)
# Soluble fiber: Soluble fiber (id: ??, ns: 0)
# Soybean: Soybean (id: ??, ns: 0)
# Soybean agglutinin: Soybean agglutinin (id: ??, ns: 0)
# Squash (plant): Squash (plant) (id: ??, ns: 0)
# Stachyose: Stachyose (id: ??, ns: 0)
# Tanzania: Tanzania (id: ??, ns: 0)
# The Beaneater: The Beaneater (id: ??, ns: 0)
# Three Sisters (agriculture): Three Sisters (agriculture) (id: ??, ns: 0)
# Tonne: Tonne (id: ??, ns: 0)
# Trellis (agriculture): Trellis (agriculture) (id: ??, ns: 0)
# UN Food and Agriculture Organization: UN Food and Agriculture Organization (id: ??, ns: 0)
# Uganda: Uganda (id: ??, ns: 0)
# United States: United States (id: ??, ns: 0)
# Usage: Usage (id: ??, ns: 0)
# Vanilla: Vanilla (id: ??, ns: 0)
# Vicia: Vicia (id: ??, ns: 0)
# Vicia faba: Vicia faba (id: ??, ns: 0)
# Vigna: Vigna (id: ??, ns: 0)
# Vigna aconitifolia: Vigna aconitifolia (id: ??, ns: 0)
# Vigna mungo: Vigna mungo (id: ??, ns: 0)
# Vigna subterranea: Vigna subterranea (id: ??, ns: 0)
# Vigna umbellata: Vigna umbellata (id: ??, ns: 0)
# Vitamin D: Vitamin D (id: ??, ns: 0)
# Wayback Machine: Wayback Machine (id: ??, ns: 0)
# West Bengal: West Bengal (id: ??, ns: 0)
# West Germanic languages: West Germanic languages (id: ??, ns: 0)
# Wikipedia:Citing sources: Wikipedia:Citing sources (id: ??, ns: 4)
# Wikipedia:Please clarify: Wikipedia:Please clarify (id: ??, ns: 4)
# Wikipedia:Protection policy: Wikipedia:Protection policy (id: ??, ns: 4)
# Yardlong bean: Yardlong bean (id: ??, ns: 0)

# %% [markdown]
# __this mere bean knows a lot of beans__

# %% [markdown]
# How many beans though does it know, and how many beans do the beans of the original bean know and how many beans do the beans of the beans of the original bean know? these questions are what Wikibeania sets out to answer

# %%
# another helper function to find beans that other beans know..
bean_regex = clean_beans.compile(r'\bbean\b|\bbeans\b', flags=clean_beans.IGNORECASE)

original_bean = wikibeania.page('Bean')
previous_beans = ['Bean']

def recurse_of_the_beans(original_bean, previous_beans):
    for new_bean in original_bean.links:
        bean_locator = bean_regex.findall(new_bean)
        if bean_locator != [] and new_bean not in previous_beans:
            new_bean_wiki = wikibeania.page(new_bean)
            previous_beans += [new_bean]
            print('OOOEEE Another Bean: ', new_bean)
            recurse_of_the_beans(new_bean_wiki, previous_beans)

# %%
recurse_of_the_beans(original_bean, previous_beans)
# Out:
# OOOEEE Another Bean:  Adzuki bean
# OOOEEE Another Bean:  Bean weevil
# OOOEEE Another Bean:  Black adzuki bean
# OOOEEE Another Bean:  White adzuki bean paste
# OOOEEE Another Bean:  Azuki bean
# OOOEEE Another Bean:  Kidney bean
# OOOEEE Another Bean:  Red beans and rice
# OOOEEE Another Bean:  15 bean soup
# OOOEEE Another Bean:  Baked beans
# OOOEEE Another Bean:  Baked bean
# OOOEEE Another Bean:  Baked bean sandwich
# OOOEEE Another Bean:  Bean dip
# OOOEEE Another Bean:  Bean pie
# OOOEEE Another Bean:  Bean salad
# OOOEEE Another Bean:  Borracho beans
# OOOEEE Another Bean:  Black turtle bean
# OOOEEE Another Bean:  Black bean (disambiguation)
# OOOEEE Another Bean:  Black Bean Games
# OOOEEE Another Bean:  Black bean sauce
# OOOEEE Another Bean:  Black bean paste
# OOOEEE Another Bean:  Fermented bean curd
# OOOEEE Another Bean:  Red bean cake
# OOOEEE Another Bean:  Cowboy beans
# OOOEEE Another Bean:  Dilly beans
# OOOEEE Another Bean:  Green bean casserole
# OOOEEE Another Bean:  Green bean
# OOOEEE Another Bean:  Common bean
# OOOEEE Another Bean:  Appaloosa bean
# OOOEEE Another Bean:  Kidney beans
# OOOEEE Another Bean:  Pinto bean
# OOOEEE Another Bean:  Refried beans
# OOOEEE Another Bean:  Guernsey Bean Jar
# OOOEEE Another Bean:  List of bean soups
# OOOEEE Another Bean:  Black bean soup
# OOOEEE Another Bean:  Broad bean
# OOOEEE Another Bean:  Black bean aphid
# OOOEEE Another Bean:  Cranberry bean
# OOOEEE Another Bean:  Flat bean
# OOOEEE Another Bean:  Jókai bean soup
# OOOEEE Another Bean:  Bean soup
# OOOEEE Another Bean:  Navy bean
# OOOEEE Another Bean:  Bean common mosaic virus
# OOOEEE Another Bean:  Lima bean
# OOOEEE Another Bean:  Lima beans
# OOOEEE Another Bean:  Navy Bean (song)
# OOOEEE Another Bean:  Red kidney bean
# OOOEEE Another Bean:  Runner bean
# OOOEEE Another Bean:  Senate bean soup
# OOOEEE Another Bean:  Rice and beans
# OOOEEE Another Bean:  Brown bean
# OOOEEE Another Bean:  Brown beans
# OOOEEE Another Bean:  Pork and beans
# OOOEEE Another Bean:  Boston baked beans
# OOOEEE Another Bean:  Original Boston Baked Beans
# OOOEEE Another Bean:  Pork and beans (disambiguation)
# OOOEEE Another Bean:  Pork And Beans War
# OOOEEE Another Bean:  Pork and Beans (plant)
# OOOEEE Another Bean:  Jelly bean
# OOOEEE Another Bean:  Jelly bean (disambiguation)
# OOOEEE Another Bean:  Android Jelly Bean
# OOOEEE Another Bean:  Template:Latest preview software release/Android Jelly Bean
# OOOEEE Another Bean:  Assorted Jelly Beans
# OOOEEE Another Bean:  Assorted Jelly Beans (album)
# OOOEEE Another Bean:  Template:Infobox album/genre/Assorted Jelly Beans (album)
# OOOEEE Another Bean:  The Jelly Beans
# OOOEEE Another Bean:  Talk:Jelly bean (disambiguation)
# OOOEEE Another Bean:  The Jelly Bean Factory
# OOOEEE Another Bean:  Pork and Beans (song)
# OOOEEE Another Bean:  File:Pork & Beans.ogg
# OOOEEE Another Bean:  Talk:Pork and beans (disambiguation)
# OOOEEE Another Bean:  Red bean paste
# OOOEEE Another Bean:  Azuki beans
# OOOEEE Another Bean:  Red bean ice
# OOOEEE Another Bean:  Red bean soup
# OOOEEE Another Bean:  Red bean porridge
# OOOEEE Another Bean:  Red bean shaved ice
# OOOEEE Another Bean:  Soy bean
# OOOEEE Another Bean:  Bean curd
# OOOEEE Another Bean:  Mung bean
# OOOEEE Another Bean:  Mung bean nuclease
# OOOEEE Another Bean:  Talk:Mung bean nuclease
# OOOEEE Another Bean:  Mung bean sprout
# OOOEEE Another Bean:  Bean sprout
# OOOEEE Another Bean:  Sweet bean sauce
# OOOEEE Another Bean:  Sweet bean paste
# OOOEEE Another Bean:  Fermented bean paste
# OOOEEE Another Bean:  Mung bean paste
# OOOEEE Another Bean:  Red bean pancake
# OOOEEE Another Bean:  Sweet Bean
# OOOEEE Another Bean:  Soup beans
# OOOEEE Another Bean:  White bean
# OOOEEE Another Bean:  Calypso bean
# OOOEEE Another Bean:  Dragon tongue bean
# OOOEEE Another Bean:  Enola bean
# OOOEEE Another Bean:  Fava bean
# OOOEEE Another Bean:  Flageolet bean
# OOOEEE Another Bean:  Green beans
# OOOEEE Another Bean:  Rattlesnake bean
# OOOEEE Another Bean:  String Beans (film)
# OOOEEE Another Bean:  String beans
# OOOEEE Another Bean:  List of diseases of the common bean
# OOOEEE Another Bean:  Bean golden mosaic virus
# OOOEEE Another Bean:  Organic beans
# OOOEEE Another Bean:  Pea bean
# OOOEEE Another Bean:  Beans
# OOOEEE Another Bean:  Bean (disambiguation)
# OOOEEE Another Bean:  BEAN (charity)
# OOOEEE Another Bean:  Bean, California
# OOOEEE Another Bean:  Bean, Kent
# OOOEEE Another Bean:  Bean (film)
# OOOEEE Another Bean:  Back to School Mr. Bean
# OOOEEE Another Bean:  Do-It-Yourself Mr. Bean
# OOOEEE Another Bean:  Goodnight Mr. Bean
# OOOEEE Another Bean:  Hair by Mr. Bean of London
# OOOEEE Another Bean:  List of Mr. Bean (animated TV series) episodes
# OOOEEE Another Bean:  List of Mr. Bean episodes
# OOOEEE Another Bean:  Bean (1997 film)
# OOOEEE Another Bean:  Merry Christmas, Mr. Bean
# OOOEEE Another Bean:  Mind the Baby, Mr. Bean
# OOOEEE Another Bean:  Mr. Bean
# OOOEEE Another Bean:  Mr. Bean's Holiday
# OOOEEE Another Bean:  Mr. Bean (Mr. Bean episode)
# OOOEEE Another Bean:  Mr. Bean (animated TV series)
# OOOEEE Another Bean:  Mr. Bean (character)
# OOOEEE Another Bean:  Mr. Bean: The Animated Series
# OOOEEE Another Bean:  Mr. Bean Goes to Town
# OOOEEE Another Bean:  Mr. Bean Rides Again
# OOOEEE Another Bean:  Mr. Bean (episode)
# OOOEEE Another Bean:  Mr. Bean in Room 426
# OOOEEE Another Bean:  Mr. Bean (animated series)
# OOOEEE Another Bean:  Tee Off, Mr. Bean
# OOOEEE Another Bean:  Mr Bean's Holiday
# OOOEEE Another Bean:  The Best Bits of Mr. Bean
# OOOEEE Another Bean:  The Curse of Mr. Bean
# OOOEEE Another Bean:  The Return of Mr. Bean
# OOOEEE Another Bean:  The Trouble with Mr. Bean
# OOOEEE Another Bean:  Template:Mr. Bean
# OOOEEE Another Bean:  Template talk:Mr. Bean
# OOOEEE Another Bean:  Talk:Mr. Bean (animated TV series)
# OOOEEE Another Bean:  Wikipedia:WikiProject Animation/A-Class review/Mr. Bean (animated TV series)
# OOOEEE Another Bean:  Wikipedia:WikiProject Animation/Peer review/Mr. Bean (animated TV series)
# OOOEEE Another Bean:  Mr Bean
# OOOEEE Another Bean:  Mr. Bean (disambiguation)
# OOOEEE Another Bean:  Mr Bean (company)
# OOOEEE Another Bean:  Soya beans
# OOOEEE Another Bean:  Talk:Mr. Bean (disambiguation)
# OOOEEE Another Bean:  Mr. Bean episode guide
# OOOEEE Another Bean:  Merry Christmas Mr. Bean
# OOOEEE Another Bean:  Template:Infobox album/genre/Bean (film)
# OOOEEE Another Bean:  Talk:Hair by Mr. Bean of London
# OOOEEE Another Bean:  Talk:Hair by Mr. Bean of London/Archive 1
# OOOEEE Another Bean:  Talk:Hair by Mr. Bean of London/Archive A
# OOOEEE Another Bean:  Wikipedia:Articles for deletion/Hair by Mr. Bean of London
# OOOEEE Another Bean:  Bean (name)
# OOOEEE Another Bean:  Alan Bean
# OOOEEE Another Bean:  Alan Bean (disambiguation)
# OOOEEE Another Bean:  Alan Bean (activist)
# OOOEEE Another Bean:  Alan Bean (song)
# OOOEEE Another Bean:  Talk:Alan Bean (disambiguation)
# OOOEEE Another Bean:  Andy Bean
# OOOEEE Another Bean:  Andy Bean (actor)
# OOOEEE Another Bean:  Anne Bean
# OOOEEE Another Bean:  Barton Appler Bean
# OOOEEE Another Bean:  Tarleton Hoffman Bean
# OOOEEE Another Bean:  Bean's bigscale
# OOOEEE Another Bean:  Bean's sawtoothed eel
# OOOEEE Another Bean:  Bean's searobin
# OOOEEE Another Bean:  Caroline van Hook Bean
# OOOEEE Another Bean:  Bean (Enderverse)
# OOOEEE Another Bean:  Beans (Looney Tunes)
# OOOEEE Another Bean:  Beans (rapper)
# OOOEEE Another Bean:  Thorns (Beans album)
# OOOEEE Another Bean:  Template:Beans (rapper)
# OOOEEE Another Bean:  Template talk:Beans (rapper)
# OOOEEE Another Bean:  Template:Infobox album/genre/Thorns (Beans album)
# OOOEEE Another Bean:  Template:Infobox musical artist/genre/Beans (rapper)
# OOOEEE Another Bean:  Beans Reardon
# OOOEEE Another Bean:  Bennett Bean
# OOOEEE Another Bean:  Cathy Bao Bean
# OOOEEE Another Bean:  Billy Bean
# OOOEEE Another Bean:  Billy Bean (disambiguation)
# OOOEEE Another Bean:  Billy Bean (footballer)
# OOOEEE Another Bean:  Billy Bean (musician)
# OOOEEE Another Bean:  Template:Infobox musical artist/genre/Billy Bean (musician)
# OOOEEE Another Bean:  Billy Bean and His Funny Machine
# OOOEEE Another Bean:  William Bean (disambiguation)
# OOOEEE Another Bean:  Bean Brothers
# OOOEEE Another Bean:  Joe Bean
# OOOEEE Another Bean:  William Bean
# OOOEEE Another Bean:  Bean Station, Tennessee
# OOOEEE Another Bean:  1972 Bean Station, Tennessee bus crash
# OOOEEE Another Bean:  Battle of Bean's Station
# OOOEEE Another Bean:  Bean's Station
# OOOEEE Another Bean:  William Bean (geologist)
# OOOEEE Another Bean:  William Bennett Bean
# OOOEEE Another Bean:  William Jackson Bean
# OOOEEE Another Bean:  George Ewart Bean
# OOOEEE Another Bean:  Willie Bean
# OOOEEE Another Bean:  Talk:William Bean (disambiguation)
# OOOEEE Another Bean:  Talk:Billy Bean (disambiguation)
# OOOEEE Another Bean:  Charles Bean
# OOOEEE Another Bean:  Charlie Bean (disambiguation)
# OOOEEE Another Bean:  Charlie Bean (economist)
# OOOEEE Another Bean:  Charlie Bean (filmmaker)
# OOOEEE Another Bean:  Talk:Charlie Bean
# OOOEEE Another Bean:  Colin Bean
# OOOEEE Another Bean:  Colter Bean
# OOOEEE Another Bean:  Talk:Colter Bean
# OOOEEE Another Bean:  Frances Bean Cobain
# OOOEEE Another Bean:  Freebie and The Bean
# OOOEEE Another Bean:  Freebie and the Bean (TV series)
# OOOEEE Another Bean:  Freebie and the Bean
# OOOEEE Another Bean:  George Bean
# OOOEEE Another Bean:  Hannibal Roy Bean
# OOOEEE Another Bean:  Hugh Bean
# OOOEEE Another Bean:  Jake Bean
# OOOEEE Another Bean:  James Bean
# OOOEEE Another Bean:  James C. Bean
# OOOEEE Another Bean:  Joel Bean
# OOOEEE Another Bean:  John Bean
# OOOEEE Another Bean:  John Bean (disambiguation)
# OOOEEE Another Bean:  John Bean (cinematographer)
# OOOEEE Another Bean:  John Bean (cricketer)
# OOOEEE Another Bean:  John Bean (explorer)
# OOOEEE Another Bean:  Talk:John Bean (disambiguation)
# OOOEEE Another Bean:  Joshua Bean
# OOOEEE Another Bean:  Josh Bean (disambiguation)
# OOOEEE Another Bean:  Josh Bean (Canadian football)
# OOOEEE Another Bean:  Talk:Josh Bean
# OOOEEE Another Bean:  Josh Bean
# OOOEEE Another Bean:  Roy Bean
# OOOEEE Another Bean:  Judge Roy Bean (TV series)
# OOOEEE Another Bean:  The Life and Times of Judge Roy Bean
# OOOEEE Another Bean:  Judge Roy Bean
# OOOEEE Another Bean:  Laura Schiff Bean
# OOOEEE Another Bean:  Marcus Bean
# OOOEEE Another Bean:  Maurice Darrow Bean
# OOOEEE Another Bean:  Talk:Maurice Darrow Bean
# OOOEEE Another Bean:  Melissa Bean
# OOOEEE Another Bean:  Mollie Bean
# OOOEEE Another Bean:  Orson Bean
# OOOEEE Another Bean:  Sawney Bean
# OOOEEE Another Bean:  Sean Bean
# OOOEEE Another Bean:  Shoshana Bean
# OOOEEE Another Bean:  The New Adventures of Beans Baxter
# OOOEEE Another Bean:  Talk:Bean (name)
# OOOEEE Another Bean:  Bean (software)
# OOOEEE Another Bean:  Template:Latest preview software release/Bean
# OOOEEE Another Bean:  Template:Latest stable software release/Bean
# OOOEEE Another Bean:  Bean (word processor)
# OOOEEE Another Bean:  Bean Cars
# OOOEEE Another Bean:  Bean Lake (Cottonwood County, Minnesota)
# OOOEEE Another Bean:  Bean Lake (Missouri)
# OOOEEE Another Bean:  Bean River
# OOOEEE Another Bean:  Beans (band)
# OOOEEE Another Bean:  Justice Bean (disambiguation)
# OOOEEE Another Bean:  Henry J. Bean
# OOOEEE Another Bean:  Henry Bean
# OOOEEE Another Bean:  Henry Bean (disambiguation)
# OOOEEE Another Bean:  William Henry Bean
# OOOEEE Another Bean:  Talk:Henry Bean (disambiguation)
# OOOEEE Another Bean:  Robert S. Bean
# OOOEEE Another Bean:  Talk:Justice Bean
# OOOEEE Another Bean:  Justice Bean
# OOOEEE Another Bean:  L.L.Bean
# OOOEEE Another Bean:  Bean Boot
# OOOEEE Another Bean:  L.L. Bean
# OOOEEE Another Bean:  Bean Boots
# OOOEEE Another Bean:  Leon Leonwood Bean
# OOOEEE Another Bean:  L. L. Bean
# OOOEEE Another Bean:  Linda Bean
# OOOEEE Another Bean:  Talk:Linda Bean
# OOOEEE Another Bean:  User:Linda Lorraine Bean
# OOOEEE Another Bean:  User talk:Linda Lorraine Bean
# OOOEEE Another Bean:  Template:Did you know nominations/Linda Bean
# OOOEEE Another Bean:  Template talk:Did you know/Linda Bean
# OOOEEE Another Bean:  Your LL Bean Boyfriend
# OOOEEE Another Bean:  Talk:Bean (disambiguation)
# OOOEEE Another Bean:  Broad beans
# OOOEEE Another Bean:  Cocoa bean
# OOOEEE Another Bean:  Coffee bean
# OOOEEE Another Bean:  The Coffee Bean & Tea Leaf
# OOOEEE Another Bean:  List of bean-to-bar chocolate manufacturers
# OOOEEE Another Bean:  Omanhene Cocoa Bean Company
# OOOEEE Another Bean:  Talk:Omanhene Cocoa Bean Company
# OOOEEE Another Bean:  Nacional (cocoa bean)
# OOOEEE Another Bean:  Talk:Cocoa bean
# OOOEEE Another Bean:  Cacao bean
# OOOEEE Another Bean:  Talk:Cocoa bean/Archive 1
# OOOEEE Another Bean:  Talk:Cocoa bean/Archive A
# OOOEEE Another Bean:  Moth bean
# OOOEEE Another Bean:  Yardlong bean
# OOOEEE Another Bean:  Bush bean
# OOOEEE Another Bean:  Pole bean
# OOOEEE Another Bean:  Dry beans
# OOOEEE Another Bean:  Dried beans
# OOOEEE Another Bean:  French beans
# OOOEEE Another Bean:  Haricot beans
# OOOEEE Another Bean:  Navy beans
# OOOEEE Another Bean:  Talk:Pea bean
# OOOEEE Another Bean:  Pinto beans
# OOOEEE Another Bean:  Talk:Jókai bean soup
# OOOEEE Another Bean:  Fermented black beans
# OOOEEE Another Bean:  Talk:Black bean
# OOOEEE Another Bean:  Black bean
# OOOEEE Another Bean:  Common beans
# OOOEEE Another Bean:  Garbanzo beans
# OOOEEE Another Bean:  Bean leafroll virus
# OOOEEE Another Bean:  Hyacinth bean
# OOOEEE Another Bean:  Wax bean
# OOOEEE Another Bean:  Beans, Beans, the Musical Fruit
# OOOEEE Another Bean:  Heinz Baked Beans
# OOOEEE Another Bean:  Navy Beans
# OOOEEE Another Bean:  The Baked Bean Museum of Excellence
# OOOEEE Another Bean:  Garbanzo bean
# OOOEEE Another Bean:  Great northern bean
# OOOEEE Another Bean:  Shell bean
# OOOEEE Another Bean:  Red bean rice
# OOOEEE Another Bean:  Talk:Red beans and rice
# OOOEEE Another Bean:  Talk:Red beans and rice/to do

# %% [markdown]
# ## HOLY BEANS!!!
# Thats a lot of beans
#
# A Dragon tongue bean, Red bean pancake, a bean film, Beans the rapper, A Battle of Bean's station.
#
# Beans continue to amaze wikibeania. And its clear that beans are often referencing other beans. What a great beanmmunity.
#
# Lets look at how many beans, each one of these beans is talking about.

# %%
number_of_bean_references = 0
number_of_bean_pages = 0
bean_text = []
for bean in previous_beans:
    new_bean = wikibeania.page(bean)
    number_of_bean_pages += 1
    bean_temp_text = new_bean.text
    bean_text.append(bean_temp_text)
    num_beans_temp = len(bean_regex.findall(bean_temp_text))
    number_of_bean_references += num_beans_temp
    print("OOOEEE check out this bean: ", bean)
    print("Look at all the beans in this bean: ", num_beans_temp)
# Out:
# OOOEEE check out this bean:  Bean
# Look at all the beans in this bean:  114
# OOOEEE check out this bean:  Adzuki bean
# Look at all the beans in this bean:  60
# OOOEEE check out this bean:  Bean weevil
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Black adzuki bean
# Look at all the beans in this bean:  13
# OOOEEE check out this bean:  White adzuki bean paste
# Look at all the beans in this bean:  64
# OOOEEE check out this bean:  Azuki bean
# Look at all the beans in this bean:  60
# OOOEEE check out this bean:  Kidney bean
# Look at all the beans in this bean:  32
# OOOEEE check out this bean:  Red beans and rice
# Look at all the beans in this bean:  19
# OOOEEE check out this bean:  15 bean soup
# Look at all the beans in this bean:  19
# OOOEEE check out this bean:  Baked beans
# Look at all the beans in this bean:  120
# OOOEEE check out this bean:  Baked bean
# Look at all the beans in this bean:  120
# OOOEEE check out this bean:  Baked bean sandwich
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Bean dip
# Look at all the beans in this bean:  46
# OOOEEE check out this bean:  Bean pie
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Bean salad
# Look at all the beans in this bean:  18
# OOOEEE check out this bean:  Borracho beans
# Look at all the beans in this bean:  13
# OOOEEE check out this bean:  Black turtle bean
# Look at all the beans in this bean:  17
# OOOEEE check out this bean:  Black bean (disambiguation)
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Black Bean Games
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Black bean sauce
# Look at all the beans in this bean:  22
# OOOEEE check out this bean:  Black bean paste
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Fermented bean curd
# Look at all the beans in this bean:  30
# OOOEEE check out this bean:  Red bean cake
# Look at all the beans in this bean:  6
# OOOEEE check out this bean:  Cowboy beans
# Look at all the beans in this bean:  14
# OOOEEE check out this bean:  Dilly beans
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Green bean casserole
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Green bean
# Look at all the beans in this bean:  50
# OOOEEE check out this bean:  Common bean
# Look at all the beans in this bean:  96
# OOOEEE check out this bean:  Appaloosa bean
# Look at all the beans in this bean:  12
# OOOEEE check out this bean:  Kidney beans
# Look at all the beans in this bean:  32
# OOOEEE check out this bean:  Pinto bean
# Look at all the beans in this bean:  33
# OOOEEE check out this bean:  Refried beans
# Look at all the beans in this bean:  15
# OOOEEE check out this bean:  Guernsey Bean Jar
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  List of bean soups
# Look at all the beans in this bean:  28
# OOOEEE check out this bean:  Black bean soup
# Look at all the beans in this bean:  13
# OOOEEE check out this bean:  Broad bean
# Look at all the beans in this bean:  142
# OOOEEE check out this bean:  Black bean aphid
# Look at all the beans in this bean:  16
# OOOEEE check out this bean:  Cranberry bean
# Look at all the beans in this bean:  23
# OOOEEE check out this bean:  Flat bean
# Look at all the beans in this bean:  13
# OOOEEE check out this bean:  Jókai bean soup
# Look at all the beans in this bean:  10
# OOOEEE check out this bean:  Bean soup
# Look at all the beans in this bean:  28
# OOOEEE check out this bean:  Navy bean
# Look at all the beans in this bean:  49
# OOOEEE check out this bean:  Bean common mosaic virus
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Lima bean
# Look at all the beans in this bean:  71
# OOOEEE check out this bean:  Lima beans
# Look at all the beans in this bean:  71
# OOOEEE check out this bean:  Navy Bean (song)
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Red kidney bean
# Look at all the beans in this bean:  32
# OOOEEE check out this bean:  Runner bean
# Look at all the beans in this bean:  27
# OOOEEE check out this bean:  Senate bean soup
# Look at all the beans in this bean:  20
# OOOEEE check out this bean:  Rice and beans
# Look at all the beans in this bean:  28
# OOOEEE check out this bean:  Brown bean
# Look at all the beans in this bean:  33
# OOOEEE check out this bean:  Brown beans
# Look at all the beans in this bean:  33
# OOOEEE check out this bean:  Pork and beans
# Look at all the beans in this bean:  13
# OOOEEE check out this bean:  Boston baked beans
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Original Boston Baked Beans
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Pork and beans (disambiguation)
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Pork And Beans War
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Pork and Beans (plant)
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Jelly bean
# Look at all the beans in this bean:  19
# OOOEEE check out this bean:  Jelly bean (disambiguation)
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Android Jelly Bean
# Look at all the beans in this bean:  11
# OOOEEE check out this bean:  Template:Latest preview software release/Android Jelly Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Assorted Jelly Beans
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Assorted Jelly Beans (album)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Template:Infobox album/genre/Assorted Jelly Beans (album)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  The Jelly Beans
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Talk:Jelly bean (disambiguation)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  The Jelly Bean Factory
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Pork and Beans (song)
# Look at all the beans in this bean:  12
# OOOEEE check out this bean:  File:Pork & Beans.ogg
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Talk:Pork and beans (disambiguation)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Red bean paste
# Look at all the beans in this bean:  64
# OOOEEE check out this bean:  Azuki beans
# Look at all the beans in this bean:  60
# OOOEEE check out this bean:  Red bean ice
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Red bean soup
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Red bean porridge
# Look at all the beans in this bean:  15
# OOOEEE check out this bean:  Red bean shaved ice
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Soy bean
# Look at all the beans in this bean:  21
# OOOEEE check out this bean:  Bean curd
# Look at all the beans in this bean:  15
# OOOEEE check out this bean:  Mung bean
# Look at all the beans in this bean:  63
# OOOEEE check out this bean:  Mung bean nuclease
# Look at all the beans in this bean:  14
# OOOEEE check out this bean:  Talk:Mung bean nuclease
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Mung bean sprout
# Look at all the beans in this bean:  21
# OOOEEE check out this bean:  Bean sprout
# Look at all the beans in this bean:  22
# OOOEEE check out this bean:  Sweet bean sauce
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Sweet bean paste
# Look at all the beans in this bean:  19
# OOOEEE check out this bean:  Fermented bean paste
# Look at all the beans in this bean:  8
# OOOEEE check out this bean:  Mung bean paste
# Look at all the beans in this bean:  63
# OOOEEE check out this bean:  Red bean pancake
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Sweet Bean
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Soup beans
# Look at all the beans in this bean:  46
# OOOEEE check out this bean:  White bean
# Look at all the beans in this bean:  96
# OOOEEE check out this bean:  Calypso bean
# Look at all the beans in this bean:  16
# OOOEEE check out this bean:  Dragon tongue bean
# Look at all the beans in this bean:  14
# OOOEEE check out this bean:  Enola bean
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Fava bean
# Look at all the beans in this bean:  142
# OOOEEE check out this bean:  Flageolet bean
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Green beans
# Look at all the beans in this bean:  50
# OOOEEE check out this bean:  Rattlesnake bean
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  String Beans (film)
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  String beans
# Look at all the beans in this bean:  50
# OOOEEE check out this bean:  List of diseases of the common bean
# Look at all the beans in this bean:  4
# OOOEEE check out this bean:  Bean golden mosaic virus
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Organic beans
# Look at all the beans in this bean:  55
# OOOEEE check out this bean:  Pea bean
# Look at all the beans in this bean:  14
# OOOEEE check out this bean:  Beans
# Look at all the beans in this bean:  114
# OOOEEE check out this bean:  Bean (disambiguation)
# Look at all the beans in this bean:  27
# OOOEEE check out this bean:  BEAN (charity)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Bean, California
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Bean, Kent
# Look at all the beans in this bean:  6
# OOOEEE check out this bean:  Bean (film)
# Look at all the beans in this bean:  51
# OOOEEE check out this bean:  Back to School Mr. Bean
# Look at all the beans in this bean:  41
# OOOEEE check out this bean:  Do-It-Yourself Mr. Bean
# Look at all the beans in this bean:  41
# OOOEEE check out this bean:  Goodnight Mr. Bean
# Look at all the beans in this bean:  28
# OOOEEE check out this bean:  Hair by Mr. Bean of London
# Look at all the beans in this bean:  41
# OOOEEE check out this bean:  List of Mr. Bean (animated TV series) episodes
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  List of Mr. Bean episodes
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Bean (1997 film)
# Look at all the beans in this bean:  51
# OOOEEE check out this bean:  Merry Christmas, Mr. Bean
# Look at all the beans in this bean:  41
# OOOEEE check out this bean:  Mind the Baby, Mr. Bean
# Look at all the beans in this bean:  39
# OOOEEE check out this bean:  Mr. Bean
# Look at all the beans in this bean:  152
# OOOEEE check out this bean:  Mr. Bean's Holiday
# Look at all the beans in this bean:  61
# OOOEEE check out this bean:  Mr. Bean (Mr. Bean episode)
# Look at all the beans in this bean:  30
# OOOEEE check out this bean:  Mr. Bean (animated TV series)
# Look at all the beans in this bean:  33
# OOOEEE check out this bean:  Mr. Bean (character)
# Look at all the beans in this bean:  27
# OOOEEE check out this bean:  Mr. Bean: The Animated Series
# Look at all the beans in this bean:  33
# OOOEEE check out this bean:  Mr. Bean Goes to Town
# Look at all the beans in this bean:  32
# OOOEEE check out this bean:  Mr. Bean Rides Again
# Look at all the beans in this bean:  43
# OOOEEE check out this bean:  Mr. Bean (episode)
# Look at all the beans in this bean:  30
# OOOEEE check out this bean:  Mr. Bean in Room 426
# Look at all the beans in this bean:  41
# OOOEEE check out this bean:  Mr. Bean (animated series)
# Look at all the beans in this bean:  33
# OOOEEE check out this bean:  Tee Off, Mr. Bean
# Look at all the beans in this bean:  38
# OOOEEE check out this bean:  Mr Bean's Holiday
# Look at all the beans in this bean:  61
# OOOEEE check out this bean:  The Best Bits of Mr. Bean
# Look at all the beans in this bean:  13
# OOOEEE check out this bean:  The Curse of Mr. Bean
# Look at all the beans in this bean:  32
# OOOEEE check out this bean:  The Return of Mr. Bean
# Look at all the beans in this bean:  30
# OOOEEE check out this bean:  The Trouble with Mr. Bean
# Look at all the beans in this bean:  27
# OOOEEE check out this bean:  Template:Mr. Bean
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Template talk:Mr. Bean
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Talk:Mr. Bean (animated TV series)
# Look at all the beans in this bean:  4
# OOOEEE check out this bean:  Wikipedia:WikiProject Animation/A-Class review/Mr. Bean (animated TV series)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Wikipedia:WikiProject Animation/Peer review/Mr. Bean (animated TV series)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Mr Bean
# Look at all the beans in this bean:  152
# OOOEEE check out this bean:  Mr. Bean (disambiguation)
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Mr Bean (company)
# Look at all the beans in this bean:  25
# OOOEEE check out this bean:  Soya beans
# Look at all the beans in this bean:  21
# OOOEEE check out this bean:  Talk:Mr. Bean (disambiguation)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Mr. Bean episode guide
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Merry Christmas Mr. Bean
# Look at all the beans in this bean:  41
# OOOEEE check out this bean:  Template:Infobox album/genre/Bean (film)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Talk:Hair by Mr. Bean of London
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Talk:Hair by Mr. Bean of London/Archive 1
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Talk:Hair by Mr. Bean of London/Archive A
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Wikipedia:Articles for deletion/Hair by Mr. Bean of London
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Bean (name)
# Look at all the beans in this bean:  68
# OOOEEE check out this bean:  Alan Bean
# Look at all the beans in this bean:  51
# OOOEEE check out this bean:  Alan Bean (disambiguation)
# Look at all the beans in this bean:  4
# OOOEEE check out this bean:  Alan Bean (activist)
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Alan Bean (song)
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Talk:Alan Bean (disambiguation)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Andy Bean
# Look at all the beans in this bean:  16
# OOOEEE check out this bean:  Andy Bean (actor)
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Anne Bean
# Look at all the beans in this bean:  22
# OOOEEE check out this bean:  Barton Appler Bean
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Tarleton Hoffman Bean
# Look at all the beans in this bean:  21
# OOOEEE check out this bean:  Bean's bigscale
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Bean's sawtoothed eel
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Bean's searobin
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Caroline van Hook Bean
# Look at all the beans in this bean:  8
# OOOEEE check out this bean:  Bean (Enderverse)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Beans (Looney Tunes)
# Look at all the beans in this bean:  24
# OOOEEE check out this bean:  Beans (rapper)
# Look at all the beans in this bean:  11
# OOOEEE check out this bean:  Thorns (Beans album)
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Template:Beans (rapper)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Template talk:Beans (rapper)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Template:Infobox album/genre/Thorns (Beans album)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Template:Infobox musical artist/genre/Beans (rapper)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Beans Reardon
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Bennett Bean
# Look at all the beans in this bean:  21
# OOOEEE check out this bean:  Cathy Bao Bean
# Look at all the beans in this bean:  24
# OOOEEE check out this bean:  Billy Bean
# Look at all the beans in this bean:  25
# OOOEEE check out this bean:  Billy Bean (disambiguation)
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Billy Bean (footballer)
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Billy Bean (musician)
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Template:Infobox musical artist/genre/Billy Bean (musician)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Billy Bean and His Funny Machine
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  William Bean (disambiguation)
# Look at all the beans in this bean:  13
# OOOEEE check out this bean:  Bean Brothers
# Look at all the beans in this bean:  73
# OOOEEE check out this bean:  Joe Bean
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  William Bean
# Look at all the beans in this bean:  10
# OOOEEE check out this bean:  Bean Station, Tennessee
# Look at all the beans in this bean:  27
# OOOEEE check out this bean:  1972 Bean Station, Tennessee bus crash
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Battle of Bean's Station
# Look at all the beans in this bean:  16
# OOOEEE check out this bean:  Bean's Station
# Look at all the beans in this bean:  27
# OOOEEE check out this bean:  William Bean (geologist)
# Look at all the beans in this bean:  4
# OOOEEE check out this bean:  William Bennett Bean
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  William Jackson Bean
# Look at all the beans in this bean:  8
# OOOEEE check out this bean:  George Ewart Bean
# Look at all the beans in this bean:  8
# OOOEEE check out this bean:  Willie Bean
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Talk:William Bean (disambiguation)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Talk:Billy Bean (disambiguation)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Charles Bean
# Look at all the beans in this bean:  74
# OOOEEE check out this bean:  Charlie Bean (disambiguation)
# Look at all the beans in this bean:  4
# OOOEEE check out this bean:  Charlie Bean (economist)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Charlie Bean (filmmaker)
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Talk:Charlie Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Colin Bean
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Colter Bean
# Look at all the beans in this bean:  13
# OOOEEE check out this bean:  Talk:Colter Bean
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Frances Bean Cobain
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Freebie and The Bean
# Look at all the beans in this bean:  14
# OOOEEE check out this bean:  Freebie and the Bean (TV series)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Freebie and the Bean
# Look at all the beans in this bean:  14
# OOOEEE check out this bean:  George Bean
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Hannibal Roy Bean
# Look at all the beans in this bean:  8
# OOOEEE check out this bean:  Hugh Bean
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Jake Bean
# Look at all the beans in this bean:  10
# OOOEEE check out this bean:  James Bean
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  James C. Bean
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Joel Bean
# Look at all the beans in this bean:  12
# OOOEEE check out this bean:  John Bean
# Look at all the beans in this bean:  25
# OOOEEE check out this bean:  John Bean (disambiguation)
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  John Bean (cinematographer)
# Look at all the beans in this bean:  10
# OOOEEE check out this bean:  John Bean (cricketer)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  John Bean (explorer)
# Look at all the beans in this bean:  4
# OOOEEE check out this bean:  Talk:John Bean (disambiguation)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Joshua Bean
# Look at all the beans in this bean:  12
# OOOEEE check out this bean:  Josh Bean (disambiguation)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Josh Bean (Canadian football)
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Talk:Josh Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Josh Bean
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Roy Bean
# Look at all the beans in this bean:  115
# OOOEEE check out this bean:  Judge Roy Bean (TV series)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  The Life and Times of Judge Roy Bean
# Look at all the beans in this bean:  30
# OOOEEE check out this bean:  Judge Roy Bean
# Look at all the beans in this bean:  115
# OOOEEE check out this bean:  Laura Schiff Bean
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Marcus Bean
# Look at all the beans in this bean:  18
# OOOEEE check out this bean:  Maurice Darrow Bean
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Talk:Maurice Darrow Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Melissa Bean
# Look at all the beans in this bean:  30
# OOOEEE check out this bean:  Mollie Bean
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Orson Bean
# Look at all the beans in this bean:  39
# OOOEEE check out this bean:  Sawney Bean
# Look at all the beans in this bean:  35
# OOOEEE check out this bean:  Sean Bean
# Look at all the beans in this bean:  58
# OOOEEE check out this bean:  Shoshana Bean
# Look at all the beans in this bean:  39
# OOOEEE check out this bean:  The New Adventures of Beans Baxter
# Look at all the beans in this bean:  17
# OOOEEE check out this bean:  Talk:Bean (name)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Bean (software)
# Look at all the beans in this bean:  20
# OOOEEE check out this bean:  Template:Latest preview software release/Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Template:Latest stable software release/Bean
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Bean (word processor)
# Look at all the beans in this bean:  20
# OOOEEE check out this bean:  Bean Cars
# Look at all the beans in this bean:  74
# OOOEEE check out this bean:  Bean Lake (Cottonwood County, Minnesota)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Bean Lake (Missouri)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Bean River
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Beans (band)
# Look at all the beans in this bean:  8
# OOOEEE check out this bean:  Justice Bean (disambiguation)
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  Henry J. Bean
# Look at all the beans in this bean:  11
# OOOEEE check out this bean:  Henry Bean
# Look at all the beans in this bean:  8
# OOOEEE check out this bean:  Henry Bean (disambiguation)
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  William Henry Bean
# Look at all the beans in this bean:  73
# OOOEEE check out this bean:  Talk:Henry Bean (disambiguation)
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Robert S. Bean
# Look at all the beans in this bean:  14
# OOOEEE check out this bean:  Talk:Justice Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Justice Bean
# Look at all the beans in this bean:  3
# OOOEEE check out this bean:  L.L.Bean
# Look at all the beans in this bean:  57
# OOOEEE check out this bean:  Bean Boot
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  L.L. Bean
# Look at all the beans in this bean:  57
# OOOEEE check out this bean:  Bean Boots
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Leon Leonwood Bean
# Look at all the beans in this bean:  24
# OOOEEE check out this bean:  L. L. Bean
# Look at all the beans in this bean:  57
# OOOEEE check out this bean:  Linda Bean
# Look at all the beans in this bean:  27
# OOOEEE check out this bean:  Talk:Linda Bean
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  User:Linda Lorraine Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  User talk:Linda Lorraine Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Template:Did you know nominations/Linda Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Template talk:Did you know/Linda Bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Your LL Bean Boyfriend
# Look at all the beans in this bean:  10
# OOOEEE check out this bean:  Talk:Bean (disambiguation)
# Look at all the beans in this bean:  9
# OOOEEE check out this bean:  Broad beans
# Look at all the beans in this bean:  142
# OOOEEE check out this bean:  Cocoa bean
# Look at all the beans in this bean:  41
# OOOEEE check out this bean:  Coffee bean
# Look at all the beans in this bean:  64
# OOOEEE check out this bean:  The Coffee Bean & Tea Leaf
# Look at all the beans in this bean:  27
# OOOEEE check out this bean:  List of bean-to-bar chocolate manufacturers
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Omanhene Cocoa Bean Company
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Talk:Omanhene Cocoa Bean Company
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Nacional (cocoa bean)
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Talk:Cocoa bean
# Look at all the beans in this bean:  21
# OOOEEE check out this bean:  Cacao bean
# Look at all the beans in this bean:  41
# OOOEEE check out this bean:  Talk:Cocoa bean/Archive 1
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Talk:Cocoa bean/Archive A
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Moth bean
# Look at all the beans in this bean:  33
# OOOEEE check out this bean:  Yardlong bean
# Look at all the beans in this bean:  20
# OOOEEE check out this bean:  Bush bean
# Look at all the beans in this bean:  96
# OOOEEE check out this bean:  Pole bean
# Look at all the beans in this bean:  96
# OOOEEE check out this bean:  Dry beans
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Dried beans
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  French beans
# Look at all the beans in this bean:  50
# OOOEEE check out this bean:  Haricot beans
# Look at all the beans in this bean:  49
# OOOEEE check out this bean:  Navy beans
# Look at all the beans in this bean:  49
# OOOEEE check out this bean:  Talk:Pea bean
# Look at all the beans in this bean:  0
# OOOEEE check out this bean:  Pinto beans
# Look at all the beans in this bean:  33
# OOOEEE check out this bean:  Talk:Jókai bean soup
# Look at all the beans in this bean:  4
# OOOEEE check out this bean:  Fermented black beans
# Look at all the beans in this bean:  22
# OOOEEE check out this bean:  Talk:Black bean
# Look at all the beans in this bean:  1
# OOOEEE check out this bean:  Black bean
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Common beans
# Look at all the beans in this bean:  96
# OOOEEE check out this bean:  Garbanzo beans
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Bean leafroll virus
# Look at all the beans in this bean:  2
# OOOEEE check out this bean:  Hyacinth bean
# Look at all the beans in this bean:  37
# OOOEEE check out this bean:  Wax bean
# Look at all the beans in this bean:  96
# OOOEEE check out this bean:  Beans, Beans, the Musical Fruit
# Look at all the beans in this bean:  8
# OOOEEE check out this bean:  Heinz Baked Beans
# Look at all the beans in this bean:  14
# OOOEEE check out this bean:  Navy Beans
# Look at all the beans in this bean:  49
# OOOEEE check out this bean:  The Baked Bean Museum of Excellence
# Look at all the beans in this bean:  5
# OOOEEE check out this bean:  Garbanzo bean
# Look at all the beans in this bean:  7
# OOOEEE check out this bean:  Great northern bean
# Look at all the beans in this bean:  96
# OOOEEE check out this bean:  Shell bean
# Look at all the beans in this bean:  96
# OOOEEE check out this bean:  Red bean rice
# Look at all the beans in this bean:  34
# OOOEEE check out this bean:  Talk:Red beans and rice
# Look at all the beans in this bean:  4
# OOOEEE check out this bean:  Talk:Red beans and rice/to do
# Look at all the beans in this bean:  0

# %%
print("Total Beans Searched: {}\nTotal Beans Referenced: {}".format(number_of_bean_pages,number_of_bean_references))
# Out:
# Total Beans Searched: 321
# Total Beans Referenced: 7401

# %% [markdown]
# __look at all of that bean knowledge__

# %% [markdown]
# Now, lets dig deeper, what are the main topic of these many beans. Is it legumes? Cooking? The Magical Fruit?
#
# Wikibeania is here to help solve these questions

# %%
# more helper beans
from sklearn.feature_extraction.text import CountVectorizer as BeanCountVectorizer
from nltk.stem import SnowballStemmer as BeanStemmer
import nltk as beanltk
import numpy as nbean
from nltk.probability import FreqDist as BeanFreqDist
stop_beans = set(beanltk.corpus.stopwords.words('english'))
#bean_stemmer = BeanStemmer(language='english')

# %%
# a little helper bean to help clean up the bean knowledge
def clean_my_beans(bean_text, stop_beans):
    bean_text = bean_text.lower() 
    bean_text = clean_beans.sub(r'[^\w\s\d]',r' ', bean_text) 
    bean_text = clean_beans.sub(r'\s+',r' ', bean_text)
    bean_text = clean_beans.sub(r'\s([^ai\d]{1}\s)',r'\1', bean_text)
    bean_text = clean_beans.sub(' [^ai]{1} ', ' ', bean_text)
    bean_text = beanltk.word_tokenize(bean_text)
    new_bean_text = []
    for bean in bean_text:
        if bean not in stop_beans:
            new_bean_text.append(bean)
    return ' '.join(new_bean_text)

# %%
clean_bean_knowledge = [clean_my_beans(bean_knowledge, stop_beans) for bean_knowledge in bean_text]

# %%
clean_bean_knowledge[0][:100]
# Out:
# 'bean seed one several genera flowering plant family fabaceae used vegetables human animal food cooke'

# %% [markdown]
# __Ah clean beans are my favorite__
#
# Now lets take a look at what these beans are talking about

# %%
bean_dist = BeanFreqDist(' '.join(clean_bean_knowledge).split(' '))
the_bean_talk = bean_dist.most_common(50)

# %%
the_bean_talk
# Out:
# [('bean', 4440),
#  ('beans', 2932),
#  ('also', 976),
#  ('used', 664),
#  ('mr', 657),
#  ('one', 514),
#  ('first', 480),
#  ('green', 428),
#  ('tofu', 399),
#  ('cocoa', 393),
#  ('red', 390),
#  ('series', 389),
#  ('may', 384),
#  ('soy', 381),
#  ('two', 377),
#  ('called', 371),
#  ('made', 368),
#  ('new', 362),
#  ('common', 344),
#  ('film', 339),
#  ('many', 337),
#  ('known', 319),
#  ('time', 293),
#  ('seeds', 287),
#  ('united', 286),
#  ('cooked', 285),
#  ('black', 282),
#  ('soybeans', 277),
#  ('protein', 276),
#  ('american', 270),
#  ('soybean', 266),
#  ('production', 264),
#  ('often', 263),
#  ('episode', 262),
#  ('dish', 256),
#  ('white', 255),
#  ('references', 244),
#  ('plant', 241),
#  ('food', 240),
#  ('broad', 234),
#  ('long', 232),
#  ('paste', 230),
#  ('world', 226),
#  ('states', 225),
#  ('rice', 225),
#  ('however', 218),
#  ('dry', 217),
#  ('like', 216),
#  ('varieties', 214),
#  ('cooking', 213)]

# %% [markdown]
# __OOOEEE Beans__ look at what these beans are talking about. Lots of references to beans, who woulda thought! Oh protein too, oooeeee beans, "mr" must be referring to mr bean oh boy never seen that movie but i heard its beanin.

# %% [markdown]
# Looking at one word frequency beantributions doesnt do a justice for the vast knowledge of beans, so lets take a look a some phrases to really see what these beans are talking about

# %%
bean_vectorizer = BeanCountVectorizer(ngram_range=(2,10)) # phrases between two and ten words
bean_frequencies = bean_vectorizer.fit_transform(clean_bean_knowledge)
bean_phrase_freqs = nbean.ravel(bean_frequencies.sum(axis=0))

# %%
bean_phrases = [k for k, v in sorted(bean_vectorizer.vocabulary_.items(), key=lambda bean_item: bean_item[1])]

# %%
import pandas as beandas
bean_phrase_df = beandas.DataFrame(bean_phrases, columns = ['bean_phrases']).\
                    join(beandas.DataFrame(bean_phrase_freqs, columns = ['bean_phrase_freqs']))

# %%
bean_phrase_df.sort_values(by = ['bean_phrase_freqs'], ascending = False, inplace = True)
bean_phrase_df.reset_index(drop = True, inplace = True)

# %%
bean_phrase_df.iloc[:50]
# Out:
#                  bean_phrases  bean_phrase_freqs
# 0                     mr bean                514
# 1               united states                207
# 2              external links                185
# 3                 broad beans                154
# 4                 green beans                142
# 5                 baked beans                141
# 6                  bean paste                138
# 7         references external                133
# 8   references external links                133
# 9                    red bean                128
# 10                   see also                108
# 11               kidney beans                106
# 12                common bean                106
# 13                   mr beans                 99
# 14                  dry beans                 85
# 15                 fava beans                 85
# 16                  mung bean                 79
# 17                 also known                 78
# 18                 beans also                 78
# 19             red bean paste                 77
# 20                   roy bean                 72
# 21                 beans used                 72
# 22                  red beans                 67
# 23                adzuki bean                 67
# 24               adzuki beans                 64
# 25             rowan atkinson                 64
# 26                  lima bean                 62
# 27         phaseolus vulgaris                 61
# 28             united kingdom                 60
# 29                  bean soup                 59
# 30                 broad bean                 59
# 31            animated series                 58
# 32             bean phaseolus                 57
# 33                 black bean                 57
# 34                 mung beans                 57
# 35                  shen gong                 56
# 36               shen gong wu                 55
# 37                    gong wu                 55
# 38              bean animated                 55
# 39                  beans may                 55
# 40           mr bean animated                 55
# 41                kidney bean                 54
# 42                  bean also                 54
# 43       bean animated series                 53
# 44    mr bean animated series                 53
# 45                dried beans                 53
# 46                  also used                 53
# 47                 pinto bean                 53
# 48                 lima beans                 53
# 49                pinto beans                 51

# %% [markdown]
#  __oh my beans, beans are for sure talking about beans!!__ What is bean phaseolus, or bean soup dont mind if I do! OOOEEE rowan atkinson must be the mr. bean. he knows what we are talking about. The united states and united kingdom must like their beans.

# %% [markdown]
# ## That's enough beans for now

# %% [markdown]
# Anyways, Wikibeania is proud to support future bean knowledge initiatives. Please feel free to reach out anytime with questions or to gain access to the Wikibeania foundation. Also please send us some bean donations and help set Bean knowledge free for all!
